# %% [markdown]
# # Monitor Web charts

# %%
import sys
sys.path.append('D:/source/repos')
from utilities.std_imports import *
from trading.Funds.FundReader import FundReader
from trading.Funds.VisualFunds import VisualFunds
from trading.Funds.Monitor import ShowInvCharts, ShowInvFTCharts
from trading.utils.DailyTrading import Stock_chart
from trading.Stocks.exchange import Exchange

# %% [markdown]
# #### Load data

# %%
fr = FundReader()
vf = VisualFunds()
ex = Exchange()
ex.load_exchange()

# %%
monitor = fr.GetFundsDf('D:/Invest/Funds/Monitor.xlsx')
monitorDf = monitor.replace(np.nan, '')
monitorDf
# Out:
#    fund_buy_isin fund_buy_curr fund_sell_isin fund_sell_curr none stock_buy  \
# 3   IE00B530N462           EUR   IE00B52VLZ70            EUR           GOOG
# 4   ES0157638000           EUR   LU0119209004            USD             KO
# 5   LU0087412390           EUR   LU0505655562            USD           CARR
# 6   LU0171310443           EUR   LU0260870158            EUR            NOW
# 7   LU0607512851           USD                                          ABT
# 8   LU0155303323           USD                                           CE
# 9   LU0130729220           USD                                          DAL
# 10  IE00B3DJ5M15           EUR                                         NCLH
# 11  LU0255976994           EUR                                          SWK
# 12                                                                      UAL
# 13                                                                      PFE
#
#    stock_sell
# 3         ACN
# 4        AMZN
# 5         CCL
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13

# %%
ml = fr.get_monitor_lists(monitor)
print('\nstock buy\n',  ml['stock_buy'])
print('\nstock sell\n', ml[ 'stock_sell'])
# Out:
# stock buy
#  ['GOOG', 'KO', 'CARR', 'NOW', 'ABT', 'CE', 'DAL', 'NCLH', 'SWK', 'UAL', 'PFE']
#
# stock sell
#  ['ACN', 'AMZN', 'CCL']

# %% [markdown]
# #### Monitor list

# %%
# Stocks to buy
[Stock_chart(sb, ndays=360) for sb in ml['stock_buy']]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
# Stocks to sell
[Stock_chart(ss, ndays=360) for ss in ml['stock_sell']]
# Out:
# [None, None, None, None]

# %% [markdown]
# #### Web chart

# %%
for sb in ml['stock_buy']:
    vf.ShowTVStockChart(sb, ex.get_exchange(sb))
    input()
