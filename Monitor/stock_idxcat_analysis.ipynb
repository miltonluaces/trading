# %% [markdown]
# # Stock Index/Category analysis

# %%
import sys
sys.path.append('D:/source/repos')
from utilities.std_imports import *
import sqlite3 as sql
from trading.Funds.VisualFunds import VisualFunds
from trading.Stocks.exchange import Exchange
from trading.utils.DailyTrading import Stock_chart

# %%
vf = VisualFunds()
ex = Exchange()
ex.load_exchange()
df = pd.read_csv('D:/Invest/data/stock_hist/idxcat_analysis.csv')
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#   ticker   stk1   stk2  stk3   stk4   stk5   stk6  idx1   idx2   idx3  ...  \
# 0      A   1.25   8.32  9.62  15.29  21.35  30.43   9.6  12.47  12.68  ...
# 1    AAL   1.32  -4.05 -2.98   3.49 -23.02  27.97   9.6  12.47  12.68  ...
# 2    AAP  -6.23  -5.40 -9.95   0.90  -2.01   4.05   9.6  12.47  12.68  ...
# 3   AAPL  -1.13   7.38  1.62  22.56  33.57  49.52   9.6  12.47  12.68  ...
# 4   ABBV  15.39  10.66  2.80  -1.12   1.99   9.27   9.6  12.47  12.68  ...
#
#    didx3  didx4  didx5  didx6  dcat1  dcat2  dcat3  dcat4  dcat5  dcat6
# 0  -3.06  -2.63   2.75  -0.03  -8.35  -4.15  -3.06  -2.63   2.75  -0.03
# 1 -15.66 -14.43 -41.62  -2.49  -8.28 -16.52 -15.66 -14.43 -41.62  -2.49
# 2 -22.63 -17.02 -20.61 -26.41 -15.83 -17.87 -22.63 -17.02 -20.61 -26.41
# 3 -11.06   4.64  14.97  19.06 -10.73  -5.09 -11.06   4.64  14.97  19.06
# 4  -9.88 -19.04 -16.61 -21.19   5.79  -1.81  -9.88 -19.04 -16.61 -21.19
#
# [5 rows x 31 columns]

# %%
conn = sql.connect('db')
df.to_sql('stock', conn)

# %%
res = pd.read_sql("SELECT * FROM stock WHERE stk1>7 and stk2>10 and stk3>15 and stk4>20 and stk5>25 and stk6>35 and didx1>5 and didx2>2 and didx2>7 and didx3>10  \
                  and didx4>15 and didx5>20 and didx6>25 and dcat1>5 and dcat2>7 and dcat3>10 and dcat4>15 and dcat5>20 and dcat6>25" , conn)
print(res.shape[0])
res.head()
# Out:
# 15
#    index ticker   stk1   stk2   stk3   stk4   stk5   stk6  idx1   idx2  ...  \
# 0     23    ALB  33.84  25.24  35.20  41.14  56.22  93.74   9.6  12.47  ...
# 1     24   ALGN  30.28  34.22  44.96  37.01  64.96  94.43   9.6  12.47  ...
# 2     45   APTV  15.75  29.69  33.22  40.08  43.54  56.25   9.6  12.47  ...
# 3    127    DFS  17.05  28.05  49.88  51.95  39.17  86.14   9.6  12.47  ...
# 4    170   EXPE  33.32  27.59  39.79  42.30  43.92  56.27   9.6  12.47  ...
#
#    didx3  didx4  didx5  didx6  dcat1  dcat2  dcat3  dcat4  dcat5  dcat6
# 0  22.52  23.22  37.62  63.28  24.24  12.77  22.52  23.22  37.62  63.28
# 1  32.28  19.09  46.36  63.97  20.68  21.75  32.28  19.09  46.36  63.97
# 2  20.54  22.16  24.94  25.79   6.15  17.22  20.54  22.16  24.94  25.79
# 3  37.20  34.03  20.57  55.68   7.45  15.58  37.20  34.03  20.57  55.68
# 4  27.11  24.38  25.32  25.81  23.72  15.12  27.11  24.38  25.32  25.81
#
# [5 rows x 32 columns]

# %%
stocks = list(res['ticker'])

# %%
[Stock_chart(s, ndays=360) for s in stocks]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
for s in stocks:
    vf.ShowTVStockChart(s, ex.get_exchange(s))
    input()
