# %% [markdown]
# # Swing Trading

# %%
import sys
sys.path.append('D:/source/repos')
from utilities.std_imports import *
from trading.Stocks.Swing import *
from trading.Stocks.StockProcess import *

# %% [markdown]
# #### Review Portfolio (pre)

# %%
GetPortfolioStocks()
# Out:
#    ticker                        name  shares  purchvalue  currvalue  \
# 0     ACN               Accenture plc   221.0      141.45     204.01
# 1    AMZN            Amazon.com, Inc.     2.0     1723.34    2659.74
# 2     CCL  Carnival Corporation & Plc    45.0       22.83      14.45
# 3  DPW.DE                  Deutch P W    35.0       29.51      38.76
# 4    JETS                 JETS Global   140.0       17.44      17.24
# 5     VOO              Vanguard SP500    10.0      238.95     277.79
#
#    purchAmount  currAmount      diff  relDiff   prop
# 0     31260.45    45086.21  13825.76    44.23  78.27
# 1      3446.68     5319.48   1872.80    54.34   9.23
# 2      1027.35      650.25   -377.10   -36.71   1.13
# 3      1032.85     1356.60    323.75    31.35   2.36
# 4      2441.60     2413.60    -28.00    -1.15   4.19
# 5      2389.50     2777.90    388.40    16.25   4.82

# %% [markdown]
# #### Register Stock operations

# %%
sso = GetStockSwingOperations()
RegisterSwingOperations(sso)
ps_post = GetPortfolioStocks()
# Out:
# MSFT position closed.
# row[1]['ticker'] position closed in portfolio and added realized P&L.
#
#  Operations registered.

# %% [markdown]
# #### Review Portfolio (post)

# %%
GetPortfolioStocks()
# Out:
#    ticker                        name  shares  purchvalue  currvalue  \
# 0     ACN               Accenture plc   221.0      141.45     204.01
# 1    AMZN            Amazon.com, Inc.     2.0     1723.34    2659.74
# 2     CCL  Carnival Corporation & Plc    45.0       22.83      14.45
# 3  DPW.DE                  Deutch P W    35.0       29.51      38.76
# 4    JETS                 JETS Global   140.0       17.44      17.24
# 5     VOO              Vanguard SP500    10.0      238.95     277.79
#
#    purchAmount  currAmount      diff  relDiff   prop
# 0     31260.45    45086.21  13825.76    44.23  78.27
# 1      3446.68     5319.48   1872.80    54.34   9.23
# 2      1027.35      650.25   -377.10   -36.71   1.13
# 3      1032.85     1356.60    323.75    31.35   2.36
# 4      2441.60     2413.60    -28.00    -1.15   4.19
# 5      2389.50     2777.90    388.40    16.25   4.82
