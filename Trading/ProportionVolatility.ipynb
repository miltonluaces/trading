# %%
import os
os.chdir('D:/source/repos')
os.getcwd()
# Out:
# 'D:\\source\\repos'

# %%
import numpy as np
import yahoo_fin.stock_info as si
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb; sb.set()
import trading.Funds
from trading.Funds.FundReader import FundReader
from trading.Funds.DBMgr import DBMgr
from trading.Funds.Monitor import *
from trading.Funds.VisualFunds import VisualFunds

# %% [markdown]
# ### Update database

# %%
Initialize()
UpdateProportionVolatility()
# Out:
# Updating Fund Values...
#
# LU0122379950 53.28 47.19
# LU0386882277 271.26 271.26
# LU1594335520 105.07 105.07
# LU0011963328 46.17 28.51
# LU0026741651 779.78 717.73
# LU0171310443 45.52 45.52
# LU0836513001 226.1 200.26
# LU0505655562 6.48 5.74
# LU0097036916 28.4 25.15
# LU0335216932 89.79 89.79
# LU1684797787 310.22 274.77
# No data for  LU0072913022
# LU0329931090 6.96 6.16
# LU0260869739 18.98 18.98
# LU0243957742 20.48 20.48
# IE00B29M2H10 2.72 2.72
# LU0260870158 24.59 24.59
# LU0094560744 34.74 34.74
# LU0366534344 220.38 220.38
# IE00B03HCZ61 26.19 26.19
# IE00B530N462 18.93 18.93
# LU0049842262 2380.33 2108.32
# LU1548497772 164.45 164.45
# IE0002639668 35.11 31.1
# LU1731833304 9.86 9.86
# LU0267388220 26.18 26.18
# LU0050372472 30.17 30.17
# LU0607516092 18.14 18.14
# ES0155844030 35.91 35.91
# LU0087412390 130.24 130.24
# LU1700711077 141.11 141.11
# LU0503631714 232.16 232.16
# ES0157638000 10.32 10.32
# LU0996182563 180.72 180.72
# IE00B52VLZ70 7.17 7.17
# LU0306632414 30.4 30.4
# LU0119209004 2427.5 2150.1
#
# Updating Stock Values...
#
# ACN 208.9029998779297 185.03
# AMZN 2479.969970703125 2196.57
# DPW.DE 31.690000534057617 31.69
# VOO 294.4656066894531 260.82
# MCHI 64.83000183105469 57.42
# JETS 20.610300064086914 18.26
#
# Updating Proportions...
#
#
# Updating Volatilities...
#
# LU0386882277 16.12
# LU1594335520 12.5
# LU0011963328 17.84
# LU0026741651 14.09
# LU0171310443 21.26
# LU0836513001 16.85
# LU0122379950 13.63
# LU0505655562 33.02
# LU0097036916 18.27
# LU0335216932 13.07
# LU1684797787 -1
# LU0329931090 22.99
# LU0072913022 17.1
# LU0260869739 19.14
# LU0243957742 8.73
# IE00B29M2H10 14.33
# LU0260870158 20.49
# LU0094560744 15.69
# LU0366534344 12.78
# IE00B03HCZ61 15.5
# IE00B530N462 16.64
# LU0049842262 21.67
# LU1548497772 23.3
# IE0002639668 16.5
# LU1731833304 -1
# LU0267388220 1.94
# LU0050372472 4.01
# LU0607516092 15.22
# ES0155844030 8.97
# LU0087412390 3.78
# LU1700711077 -1
# LU0503631714 16.29
# ES0157638000 25.84
# LU0996182563 15.79
# IE00B52VLZ70 15.33
# LU0306632414 20.0
# LU0119209004 12.65
#
# Updating Performance Portfolio  1  ...
#
#
# Updating Performance Portfolio  2  ...
#
#
# Updating Performance Portfolio Total ...
#
# Initialized

# %% [markdown]
# ## Volatility

# %%
df = vf.GetQueryRes('select * from propVolatil() order by propvol desc'); df

# %% [markdown]
# ## Proportion

# %%
plt.figure(figsize=(18, 18))
plt.pie(df['prop'].astype(np.float), labels=df['name'], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### Volatility

# %%
df = df.sort_values(by=['vol'], ascending=False)
f, ax = plt.subplots(figsize=(6, 15))
sb.barplot(x="vol", y="name", data=df)
sb.despine(left=True, bottom=True)

# %% [markdown]
# #### Proportion of volatility

# %%
plt.figure(figsize=(18, 18))
plt.pie(df['propvol'].astype(np.float), labels=df['name'], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### Average volatility

# %%
vf.GetQueryRes('select sum(propvol) from propVolatil()')
# Out:
#      sum
# 0  15.67
